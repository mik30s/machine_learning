# %% [markdown]
# ## Activity Classification Using Acclerometer Readings
# ***
# An attempt to classify a subjects activity at work using a kNN model.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.neighbors as KNearestNeighbors
from sklearn.model_selection import train_test_split

# %% [markdown]
# First we visualize the data we have to have an idea of what model to use.

# %%
data = pd.read_csv('data/activity_recognition/1.csv')
print(data.head())
pd.plotting.scatter_matrix(pd.DataFrame(data), alpha=0.2, figsize=(12, 12), marker='o')
plt.show()
# Out:
#      0  1502  2215  2153  1
# 0  1.0  1667  2072  2047  1
# 1  2.0  1611  1957  1906  1
# 2  3.0  1601  1939  1831  1
# 3  4.0  1643  1965  1879  1
# 4  5.0  1604  1959  1921  1
