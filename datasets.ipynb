# %% [markdown]
# ### Forged Dataset

# %%
import mglearn
import matplotlib.pyplot as plt
X, y = mglearn.datasets.make_forge()
print(X.shape)
print(y.shape)
mglearn.discrete_scatter(X[:,0], X[:,1], y)
plt.show()
# Out:
# (26, 2)
# (26,)

# %% [markdown]
# ***
# ### Wave dataset
# Giving an `X` predict a continous value `y`

# %%
X, y  = mglearn.datasets.make_wave(n_samples=500)
print(X.shape, y.shape)
mglearn.discrete_scatter(X, y)
plt.show()
# Out:
# (500, 1) (500,)

# %% [markdown]
# ***
# ### Cancer Tumors

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()

print(cancer.keys())
print(cancer['feature_names'][:5])
print(cancer.data[:5,5])
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness']
# [ 0.2776   0.07864  0.1599   0.2839   0.1328 ]

# %% [markdown]
# ***
# ### Boston House Prices
# Giving a house size and some other features predict its price

# %%
from sklearn.datasets import load_boston
boston = load_boston()

print(boston.keys())
print(boston.data.shape)
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])
# (506, 13)
